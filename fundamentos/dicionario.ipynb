# %% [markdown]
# # Dicionário

# %% [markdown]
# ### Pegar item

# %%
mais_vendidos = {'tecnologia': 'iphone', 'refrigeracao': 'ar consul', 'livros': '48 leis do poder'}

print(mais_vendidos['tecnologia'])
print(mais_vendidos.get('refrigeracao'))
# Out:
# iphone
# ar consul

# %% [markdown]
# ###
