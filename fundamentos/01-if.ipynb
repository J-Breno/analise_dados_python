# %% [markdown]
# # IF

# %% [markdown]
# ### If - Estrutura básica

# %%
meta = 5000
qtde_vendida = 30000

if qtde_vendida > meta:
    print('Batemos a meta de vendas de Iphone, vendemos {} unidades'.format(qtde_vendida))
else:
    print('Infelizmente não batemos a meta, pois a meta seria {} unidades e vendemos {} unidades'.format(meta, qtde_vendida))
# Out:
# Batemos a meta de vendas de Iphone, vendemos 30000 unidades

# %% [markdown]
# ### If - Blocos e identação

# %%
meta = 0.85
taxa = 0
rendimento = 0.01

if rendimento > meta:
    if rendimento > 0.20:
        taxa = 0.04
        print(f'A taxa foi de {taxa}')
    else:
        taxa = 0.02
        print(f'A taxa foi de {taxa}')
else:
    taxa = 0
    print(f'A taxa foi de {taxa}')
# Out:
#   Cell In[2], line 8
#     print(`A taxa foi de {`)
#                            ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '{'
