# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5, 4), index=['A', 'B', 'C', 'D', 'E'], columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  0.556868  1.338454  0.242946 -0.774154
# B -0.666038 -1.883245  0.179562  1.030169
# C -0.437163  1.274623 -0.975194  1.432736
# D -1.276206 -0.179626  1.794092 -0.072935
# E -0.173002  0.814258  0.372984  0.696560

# %%
df['W']
# Out:
# A    0.556868
# B   -0.666038
# C   -0.437163
# D   -1.276206
# E   -0.173002
# Name: W, dtype: float64

# %%
df[['W']]
# Out:
#           W
# A  0.556868
# B -0.666038
# C -0.437163
# D -1.276206
# E -0.173002

# %%
df['new'] = df['W']
df
# Out:
#           W         X         Y         Z       new
# A  0.556868  1.338454  0.242946 -0.774154  0.556868
# B -0.666038 -1.883245  0.179562  1.030169 -0.666038
# C -0.437163  1.274623 -0.975194  1.432736 -0.437163
# D -1.276206 -0.179626  1.794092 -0.072935 -1.276206
# E -0.173002  0.814258  0.372984  0.696560 -0.173002

# %%
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  0.556868  1.338454  0.242946 -0.774154  0.799814
# B -0.666038 -1.883245  0.179562  1.030169 -0.486477
# C -0.437163  1.274623 -0.975194  1.432736 -1.412357
# D -1.276206 -0.179626  1.794092 -0.072935  0.517886
# E -0.173002  0.814258  0.372984  0.696560  0.199982

# %%
df.drop('new', axis=1)
# Out:
#           W         X         Y         Z
# A  0.556868  1.338454  0.242946 -0.774154
# B -0.666038 -1.883245  0.179562  1.030169
# C -0.437163  1.274623 -0.975194  1.432736
# D -1.276206 -0.179626  1.794092 -0.072935
# E -0.173002  0.814258  0.372984  0.696560

# %%
df.drop('new', axis=1, inplace=True)

# %%
df.loc['A']
# Out:
# W    0.556868
# X    1.338454
# Y    0.242946
# Z   -0.774154
# Name: A, dtype: float64

# %%
df.iloc[0, 2]
# Out:
# np.float64(0.24294560273339133)
