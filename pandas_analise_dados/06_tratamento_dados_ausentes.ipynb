# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'A': [1, 2, np.nan],
    'B': [5, np.nan, np.nan],
    'C': [1, 2, 3]
})

# %%
df.dropna(axis=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1, thresh=2)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3
