# %%
import pandas as pd
# Cria um DataFrame
data = {'Classe':['Júnior','Júnior','Pleno','Pleno','Sênior','Sênior'],
       'Nome':['Jorge','Carlos','Roberta','Patrícia','Bruno','Vera'],
       'Venda':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
grup = df.groupby('Classe')

# %%
grup.sum()
# Out:
#                    Nome  Venda
# Classe
# Júnior      JorgeCarlos    320
# Pleno   RobertaPatrícia    464
# Sênior        BrunoVera    593

# %%
df2 = df.copy()

# %%
df2['Venda'] = [150, 432, 190, 230, 410, 155]

# %%
df
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
df2
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
df2.groupby(['Classe', 'Nome']).sum()
# Out:
#                  Venda
# Classe Nome
# Júnior Carlos      120
#        Jorge       200
# Pleno  Patrícia    124
#        Roberta     340
# Sênior Bruno       243
#        Vera        350
