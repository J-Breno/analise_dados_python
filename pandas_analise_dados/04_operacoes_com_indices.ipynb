# %%
import pandas as pd
import numpy as np
from numpy.random import randn
df = pd.DataFrame(randn(5, 4), index=['A', 'B', 'C', 'D', 'E'], columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  0.716139 -0.155972  0.406646  0.289742
# B  2.010398  0.308676  2.122100 -1.202193
# C  1.705238  0.938822 -0.806066 -1.245814
# D  0.803721 -0.311212  1.241239  1.028478
# E -1.727309 -1.334725  0.637753  0.763036

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='str')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='str')
